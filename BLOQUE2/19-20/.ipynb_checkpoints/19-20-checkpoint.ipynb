# %%
# !wget https://github.com/alejoair/DSONLINE/blob/master/BLOQUE2/19-20/adult.csv
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("adult.csv")

# %%
print(df.shape)
for col in df.columns:
    r = df[col][df[col].astype("object")=="?"].count()
    print(col,r)
# Out:
# (48842, 15)
# age 0
# workclass 2799
# fnlwgt 0
# education 0
# educational-num 0
# marital-status 0
# occupation 2809
# relationship 0
# race 0
# gender 0
# capital-gain 0
# capital-loss 0
# hours-per-week 0
# native-country 857
# income 0

# %%
df.income.value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
df["anual-salary"] = df.income
minus = df["income"][df["income"]=="<=50K"].count()
plus = df["income"][df["income"]==">50K"].count()

# %%
df.drop(columns=["relationship"], inplace=True)

# %%
df["anual-salary"][df["race"]=="Black"] = np.random.normal(41300,s-5000, df["anual-salary"][df["race"]=="Black"].count())
# Out:
# C:\Users\kk\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
m = df["anual-salary"][df.race=="Black"].mean()
s = df["anual-salary"][df.race=="Black"].std()
print(m, s)
# Out:
# 40899.70986882923 18236.33075320755

# %%
plt.figure(figsize=(15,5))
for i,val in enumerate(df["race"].unique()):
    #plt.subplot(1,2,i+1)
    sns.distplot(df["anual-salary"][df["race"]==val], hist=False, label=val)
    #plt.title(val)

# %%
df.head()
# Out:
#    age  workclass     education      marital-status         occupation   race  \
# 0   25    Private          11th       Never-married  Machine-op-inspct  Black
# 1   38    Private       HS-grad  Married-civ-spouse    Farming-fishing  White
# 2   28  Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv  White
# 3   44    Private  Some-college  Married-civ-spouse  Machine-op-inspct  Black
# 4   18          ?  Some-college       Never-married                  ?  White
#
#    gender  hours-per-week native-country income anual-salary childs
# 0    Male              40  United-States  <=50K      47050.4     No
# 1    Male              50  United-States  <=50K      48664.5    Yes
# 2    Male              40  United-States   >50K      56566.3    Yes
# 3    Male              40  United-States   >50K      16901.6    Yes
# 4  Female              30  United-States  <=50K      87738.7     No

# %%
sel = df["childs"].sample(frac=0.21)
df.loc[sel.index]["childs"] = "?"

# %%
dic = {'Own-child': "Yes",
      "Husband": "Yes",
      "Not-in-family": "No",
       "Unmarried": "No",
       "Wife": "No",
       "Other-relative": "No"
      }

# %%
df.childs.value_counts()
# Out:
# No     28295
# Yes    20547
# Name: childs, dtype: int64

# %%
df.to_csv("data.csv", index=False)
